# %%
conda install -c conda-forge fbprophet
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\A\anaconda3
#
#   added / updated specs:
#     - fbprophet
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.12.5  |       h5b45459_0         173 KB  conda-forge
#     certifi-2020.12.5          |   py37h03978a9_1         143 KB  conda-forge
#     conda-4.9.2                |   py37h03978a9_0         3.0 MB  conda-forge
#     convertdate-2.1.3          |          py_1000          30 KB  conda-forge
#     ephem-3.7.7.1              |   py37h4ab8f01_1         715 KB  conda-forge
#     fbprophet-0.7.1            |   py37h1834ac0_0         567 KB  conda-forge
#     holidays-0.10.4            |     pyhd8ed1ab_0          65 KB  conda-forge
#     korean_lunar_calendar-0.2.1|     pyh9f0ad1d_0          10 KB  conda-forge
#     libpython-2.0              |   py37hc8dfbb8_1          47 KB  conda-forge
#     lunarcalendar-0.0.9        |             py_0          20 KB  conda-forge
#     m2w64-binutils-2.25.1      |                5        44.3 MB  conda-forge
#     m2w64-bzip2-1.0.6          |                6         102 KB  conda-forge
#     m2w64-crt-git-5.0.0.4636.2595836|                2         3.4 MB  conda-forge
#     m2w64-gcc-5.3.0            |                6        40.8 MB  conda-forge
#     m2w64-gcc-ada-5.3.0        |                6        33.3 MB  conda-forge
#     m2w64-gcc-fortran-5.3.0    |                6        10.2 MB  conda-forge
#     m2w64-gcc-objc-5.3.0       |                6        15.2 MB  conda-forge
#     m2w64-headers-git-5.0.0.4636.c0ad18a|                2         5.6 MB  conda-forge
#     m2w64-isl-0.16.1           |                2         655 KB  conda-forge
#     m2w64-libiconv-1.14        |                6         1.5 MB  conda-forge
#     m2w64-libmangle-git-5.0.0.4509.2e5a9a2|                2          23 KB  conda-forge
#     m2w64-make-4.1.2351.a80a8b8|                2         117 KB  conda-forge
#     m2w64-mpc-1.0.3            |                3          71 KB  conda-forge
#     m2w64-mpfr-3.1.4           |                4         294 KB  conda-forge
#     m2w64-pkg-config-0.29.1    |                2         467 KB  conda-forge
#     m2w64-toolchain-5.3.0      |                7           3 KB  conda-forge
#     m2w64-tools-git-5.0.0.4592.90b8472|                2         320 KB  conda-forge
#     m2w64-windows-default-manifest-6.4|                3           5 KB  conda-forge
#     m2w64-winpthreads-git-5.0.0.4634.697f757|                2          47 KB  conda-forge
#     m2w64-zlib-1.2.8           |               10         199 KB  conda-forge
#     numpy-1.19.2               |   py37hadc3359_0          22 KB
#     numpy-base-1.19.2          |   py37ha3acd2a_0         3.8 MB
#     openssl-1.1.1i             |       h8ffe710_0         5.8 MB  conda-forge
#     pandas-1.2.0               |   py37h08fd248_0         9.9 MB  conda-forge
#     pystan-2.19.0.0            |   py37hcce6980_0        11.9 MB
#     ------------------------------------------------------------
#                                            Total:       192.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   convertdate        conda-forge/noarch::convertdate-2.1.3-py_1000
#   ephem              conda-forge/win-64::ephem-3.7.7.1-py37h4ab8f01_1
#   fbprophet          conda-forge/win-64::fbprophet-0.7.1-py37h1834ac0_0
#   holidays           conda-forge/noarch::holidays-0.10.4-pyhd8ed1ab_0
#   korean_lunar_cale~ conda-forge/noarch::korean_lunar_calendar-0.2.1-pyh9f0ad1d_0
#   libpython          conda-forge/win-64::libpython-2.0-py37hc8dfbb8_1
#   lunarcalendar      conda-forge/noarch::lunarcalendar-0.0.9-py_0
#   m2w64-binutils     conda-forge/win-64::m2w64-binutils-2.25.1-5
#   m2w64-bzip2        conda-forge/win-64::m2w64-bzip2-1.0.6-6
#   m2w64-crt-git      conda-forge/win-64::m2w64-crt-git-5.0.0.4636.2595836-2
#   m2w64-gcc          conda-forge/win-64::m2w64-gcc-5.3.0-6
#   m2w64-gcc-ada      conda-forge/win-64::m2w64-gcc-ada-5.3.0-6
#   m2w64-gcc-fortran  conda-forge/win-64::m2w64-gcc-fortran-5.3.0-6
#   m2w64-gcc-objc     conda-forge/win-64::m2w64-gcc-objc-5.3.0-6
#   m2w64-headers-git  conda-forge/win-64::m2w64-headers-git-5.0.0.4636.c0ad18a-2
#   m2w64-isl          conda-forge/win-64::m2w64-isl-0.16.1-2
#   m2w64-libiconv     conda-forge/win-64::m2w64-libiconv-1.14-6
#   m2w64-libmangle-g~ conda-forge/win-64::m2w64-libmangle-git-5.0.0.4509.2e5a9a2-2
#   m2w64-make         conda-forge/win-64::m2w64-make-4.1.2351.a80a8b8-2
#   m2w64-mpc          conda-forge/win-64::m2w64-mpc-1.0.3-3
#   m2w64-mpfr         conda-forge/win-64::m2w64-mpfr-3.1.4-4
#   m2w64-pkg-config   conda-forge/win-64::m2w64-pkg-config-0.29.1-2
#   m2w64-toolchain    conda-forge/win-64::m2w64-toolchain-5.3.0-7
#   m2w64-tools-git    conda-forge/win-64::m2w64-tools-git-5.0.0.4592.90b8472-2
#   m2w64-windows-def~ conda-forge/win-64::m2w64-windows-default-manifest-6.4-3
#   m2w64-winpthreads~ conda-forge/win-64::m2w64-winpthreads-git-5.0.0.4634.697f757-2
#   m2w64-zlib         conda-forge/win-64::m2w64-zlib-1.2.8-10
#   numpy-base         pkgs/main/win-64::numpy-base-1.19.2-py37ha3acd2a_0
#   pystan             pkgs/main/win-64::pystan-2.19.0.0-py37hcce6980_0
#
# The following packages will be UPDATED:
#
#   certifi            pkgs/main::certifi-2020.12.5-py37haa9~ --> conda-forge::certifi-2020.12.5-py37h03978a9_1
#   numpy                               1.18.1-py37h93ca92e_0 --> 1.19.2-py37hadc3359_0
#   pandas             pkgs/main::pandas-1.0.1-py37h47e9c7a_0 --> conda-forge::pandas-1.2.0-py37h08fd248_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2020.12.8-~ --> conda-forge::ca-certificates-2020.12.5-h5b45459_0
#   conda               pkgs/main::conda-4.9.2-py37haa95532_0 --> conda-forge::conda-4.9.2-py37h03978a9_0
#   openssl              pkgs/main::openssl-1.1.1i-h2bbff1b_0 --> conda-forge::openssl-1.1.1i-h8ffe710_0
#
#
#
# Downloading and Extracting Packages
#
# m2w64-toolchain-5.3. | 3 KB      |            |   0%
# m2w64-toolchain-5.3. | 3 KB      | ########## | 100%
# m2w64-toolchain-5.3. | 3 KB      | ########## | 100%
#
# conda-4.9.2          | 3.0 MB    |            |   0%
# conda-4.9.2          | 3.0 MB    | #7         |  17%
# conda-4.9.2          | 3.0 MB    | #####4     |  55%
# conda-4.9.2          | 3.0 MB    | ########8  |  88%
# conda-4.9.2          | 3.0 MB    | ########## | 100%
#
# m2w64-tools-git-5.0. | 320 KB    |            |   0%
# m2w64-tools-git-5.0. | 320 KB    | ########## | 100%
# m2w64-tools-git-5.0. | 320 KB    | ########## | 100%
#
# m2w64-headers-git-5. | 5.6 MB    |            |   0%
# m2w64-headers-git-5. | 5.6 MB    | #2         |  13%
# m2w64-headers-git-5. | 5.6 MB    | ###3       |  33%
# m2w64-headers-git-5. | 5.6 MB    | #####2     |  53%
# m2w64-headers-git-5. | 5.6 MB    | #######3   |  73%
# m2w64-headers-git-5. | 5.6 MB    | #########4 |  95%
# m2w64-headers-git-5. | 5.6 MB    | ########## | 100%
#
# openssl-1.1.1i       | 5.8 MB    |            |   0%
# openssl-1.1.1i       | 5.8 MB    |            |   0%
# openssl-1.1.1i       | 5.8 MB    | ######2    |  63%
# openssl-1.1.1i       | 5.8 MB    | ########2  |  82%
# openssl-1.1.1i       | 5.8 MB    | ########## | 100%
#
# ca-certificates-2020 | 173 KB    |            |   0%
# ca-certificates-2020 | 173 KB    | ########## | 100%
# ca-certificates-2020 | 173 KB    | ########## | 100%
#
# m2w64-binutils-2.25. | 44.3 MB   |            |   0%
# m2w64-binutils-2.25. | 44.3 MB   | 1          |   2%
# m2w64-binutils-2.25. | 44.3 MB   | 4          |   4%
# m2w64-binutils-2.25. | 44.3 MB   | 6          |   7%
# m2w64-binutils-2.25. | 44.3 MB   | 9          |   9%
# m2w64-binutils-2.25. | 44.3 MB   | #1         |  12%
# m2w64-binutils-2.25. | 44.3 MB   | #4         |  14%
# m2w64-binutils-2.25. | 44.3 MB   | #6         |  17%
# m2w64-binutils-2.25. | 44.3 MB   | #9         |  19%
# m2w64-binutils-2.25. | 44.3 MB   | ##2        |  22%
# m2w64-binutils-2.25. | 44.3 MB   | ##4        |  25%
# m2w64-binutils-2.25. | 44.3 MB   | ##7        |  27%
# m2w64-binutils-2.25. | 44.3 MB   | ##9        |  30%
# m2w64-binutils-2.25. | 44.3 MB   | ###2       |  32%
# m2w64-binutils-2.25. | 44.3 MB   | ###4       |  35%
# m2w64-binutils-2.25. | 44.3 MB   | ###7       |  37%
# m2w64-binutils-2.25. | 44.3 MB   | ####       |  40%
# m2w64-binutils-2.25. | 44.3 MB   | ####2      |  43%
# m2w64-binutils-2.25. | 44.3 MB   | ####5      |  45%
# m2w64-binutils-2.25. | 44.3 MB   | ####7      |  48%
# m2w64-binutils-2.25. | 44.3 MB   | #####      |  50%
# m2w64-binutils-2.25. | 44.3 MB   | #####3     |  54%
# m2w64-binutils-2.25. | 44.3 MB   | #####6     |  57%
# m2w64-binutils-2.25. | 44.3 MB   | #####9     |  59%
# m2w64-binutils-2.25. | 44.3 MB   | ######1    |  61%
# m2w64-binutils-2.25. | 44.3 MB   | ######4    |  64%
# m2w64-binutils-2.25. | 44.3 MB   | ######6    |  67%
# m2w64-binutils-2.25. | 44.3 MB   | ######9    |  69%
# m2w64-binutils-2.25. | 44.3 MB   | #######1   |  72%
# m2w64-binutils-2.25. | 44.3 MB   | #######4   |  74%
# m2w64-binutils-2.25. | 44.3 MB   | #######6   |  77%
# m2w64-binutils-2.25. | 44.3 MB   | #######9   |  79%
# m2w64-binutils-2.25. | 44.3 MB   | ########1  |  82%
# m2w64-binutils-2.25. | 44.3 MB   | ########4  |  85%
# m2w64-binutils-2.25. | 44.3 MB   | ########7  |  87%
# m2w64-binutils-2.25. | 44.3 MB   | ########9  |  90%
# m2w64-binutils-2.25. | 44.3 MB   | #########2 |  92%
# m2w64-binutils-2.25. | 44.3 MB   | #########4 |  95%
# m2w64-binutils-2.25. | 44.3 MB   | #########7 |  97%
# m2w64-binutils-2.25. | 44.3 MB   | #########9 | 100%
# m2w64-binutils-2.25. | 44.3 MB   | ########## | 100%
#
# m2w64-zlib-1.2.8     | 199 KB    |            |   0%
# m2w64-zlib-1.2.8     | 199 KB    | ########## | 100%
# m2w64-zlib-1.2.8     | 199 KB    | ########## | 100%
#
# m2w64-mpc-1.0.3      | 71 KB     |            |   0%
# m2w64-mpc-1.0.3      | 71 KB     | ########## | 100%
# m2w64-mpc-1.0.3      | 71 KB     | ########## | 100%
#
# m2w64-mpfr-3.1.4     | 294 KB    |            |   0%
# m2w64-mpfr-3.1.4     | 294 KB    | ########## | 100%
# m2w64-mpfr-3.1.4     | 294 KB    | ########## | 100%
#
# m2w64-winpthreads-gi | 47 KB     |            |   0%
# m2w64-winpthreads-gi | 47 KB     | ########## | 100%
# m2w64-winpthreads-gi | 47 KB     | ########## | 100%
#
# pandas-1.2.0         | 9.9 MB    |            |   0%
# pandas-1.2.0         | 9.9 MB    | 7          |   8%
# pandas-1.2.0         | 9.9 MB    | #9         |  19%
# pandas-1.2.0         | 9.9 MB    | ##5        |  26%
# pandas-1.2.0         | 9.9 MB    | ###7       |  37%
# pandas-1.2.0         | 9.9 MB    | ####8      |  49%
# pandas-1.2.0         | 9.9 MB    | ######     |  60%
# pandas-1.2.0         | 9.9 MB    | #######1   |  71%
# pandas-1.2.0         | 9.9 MB    | ########3  |  84%
# pandas-1.2.0         | 9.9 MB    | #########5 |  96%
# pandas-1.2.0         | 9.9 MB    | ########## | 100%
#
# fbprophet-0.7.1      | 567 KB    |            |   0%
# fbprophet-0.7.1      | 567 KB    | ########## | 100%
# fbprophet-0.7.1      | 567 KB    | ########## | 100%
#
# m2w64-gcc-objc-5.3.0 | 15.2 MB   |            |   0%
# m2w64-gcc-objc-5.3.0 | 15.2 MB   | 5          |   5%
# m2w64-gcc-objc-5.3.0 | 15.2 MB   | #2         |  13%
# m2w64-gcc-objc-5.3.0 | 15.2 MB   | ##2        |  22%
# m2w64-gcc-objc-5.3.0 | 15.2 MB   | ##9        |  30%
# m2w64-gcc-objc-5.3.0 | 15.2 MB   | ###7       |  37%
# m2w64-gcc-objc-5.3.0 | 15.2 MB   | ####4      |  45%
# m2w64-gcc-objc-5.3.0 | 15.2 MB   | #####2     |  52%
# m2w64-gcc-objc-5.3.0 | 15.2 MB   | #####9     |  60%
# m2w64-gcc-objc-5.3.0 | 15.2 MB   | ######7    |  67%
# m2w64-gcc-objc-5.3.0 | 15.2 MB   | #######4   |  75%
# m2w64-gcc-objc-5.3.0 | 15.2 MB   | ########2  |  83%
# m2w64-gcc-objc-5.3.0 | 15.2 MB   | #########  |  90%
# m2w64-gcc-objc-5.3.0 | 15.2 MB   | #########7 |  98%
# m2w64-gcc-objc-5.3.0 | 15.2 MB   | ########## | 100%
#
# numpy-base-1.19.2    | 3.8 MB    |            |   0%
# numpy-base-1.19.2    | 3.8 MB    | 7          |   7%
# numpy-base-1.19.2    | 3.8 MB    | ###5       |  35%
# numpy-base-1.19.2    | 3.8 MB    | ######5    |  66%
# numpy-base-1.19.2    | 3.8 MB    | #########5 |  96%
# numpy-base-1.19.2    | 3.8 MB    | ########## | 100%
#
# m2w64-isl-0.16.1     | 655 KB    |            |   0%
# m2w64-isl-0.16.1     | 655 KB    | #########2 |  93%
# m2w64-isl-0.16.1     | 655 KB    | ########## | 100%
#
# korean_lunar_calenda | 10 KB     |            |   0%
# korean_lunar_calenda | 10 KB     | ########## | 100%
# korean_lunar_calenda | 10 KB     | ########## | 100%
#
# m2w64-libiconv-1.14  | 1.5 MB    |            |   0%
# m2w64-libiconv-1.14  | 1.5 MB    | ####9      |  50%
# m2w64-libiconv-1.14  | 1.5 MB    | ########## | 100%
# m2w64-libiconv-1.14  | 1.5 MB    | ########## | 100%
#
# numpy-1.19.2         | 22 KB     |            |   0%
# numpy-1.19.2         | 22 KB     | ########## | 100%
# numpy-1.19.2         | 22 KB     | ########## | 100%
#
# m2w64-crt-git-5.0.0. | 3.4 MB    |            |   0%
# m2w64-crt-git-5.0.0. | 3.4 MB    | ##2        |  22%
# m2w64-crt-git-5.0.0. | 3.4 MB    | #####5     |  56%
# m2w64-crt-git-5.0.0. | 3.4 MB    | ########9  |  89%
# m2w64-crt-git-5.0.0. | 3.4 MB    | ########## | 100%
#
# lunarcalendar-0.0.9  | 20 KB     |            |   0%
# lunarcalendar-0.0.9  | 20 KB     | ########## | 100%
#
# certifi-2020.12.5    | 143 KB    |            |   0%
# certifi-2020.12.5    | 143 KB    | ########## | 100%
# certifi-2020.12.5    | 143 KB    | ########## | 100%
#
# convertdate-2.1.3    | 30 KB     |            |   0%
# convertdate-2.1.3    | 30 KB     | ########## | 100%
# convertdate-2.1.3    | 30 KB     | ########## | 100%
#
# m2w64-gcc-fortran-5. | 10.2 MB   |            |   0%
# m2w64-gcc-fortran-5. | 10.2 MB   | 6          |   7%
# m2w64-gcc-fortran-5. | 10.2 MB   | #8         |  18%
# m2w64-gcc-fortran-5. | 10.2 MB   | ##9        |  29%
# m2w64-gcc-fortran-5. | 10.2 MB   | ####       |  41%
# m2w64-gcc-fortran-5. | 10.2 MB   | #####2     |  52%
# m2w64-gcc-fortran-5. | 10.2 MB   | ######1    |  61%
# m2w64-gcc-fortran-5. | 10.2 MB   | #######4   |  74%
# m2w64-gcc-fortran-5. | 10.2 MB   | ########5  |  86%
# m2w64-gcc-fortran-5. | 10.2 MB   | #########6 |  97%
# m2w64-gcc-fortran-5. | 10.2 MB   | ########## | 100%
#
# m2w64-pkg-config-0.2 | 467 KB    |            |   0%
# m2w64-pkg-config-0.2 | 467 KB    | ########## | 100%
# m2w64-pkg-config-0.2 | 467 KB    | ########## | 100%
#
# ephem-3.7.7.1        | 715 KB    |            |   0%
# ephem-3.7.7.1        | 715 KB    | #####5     |  56%
# ephem-3.7.7.1        | 715 KB    | ########## | 100%
# ephem-3.7.7.1        | 715 KB    | ########## | 100%
#
# m2w64-make-4.1.2351. | 117 KB    |            |   0%
# m2w64-make-4.1.2351. | 117 KB    | ########## | 100%
#
# libpython-2.0        | 47 KB     |            |   0%
# libpython-2.0        | 47 KB     | ###3       |  34%
# libpython-2.0        | 47 KB     | ########## | 100%
#
# pystan-2.19.0.0      | 11.9 MB   |            |   0%
# pystan-2.19.0.0      | 11.9 MB   | 7          |   7%
# pystan-2.19.0.0      | 11.9 MB   | #6         |  17%
# pystan-2.19.0.0      | 11.9 MB   | ##5        |  25%
# pystan-2.19.0.0      | 11.9 MB   | ###5       |  35%
# pystan-2.19.0.0      | 11.9 MB   | ####1      |  42%
# pystan-2.19.0.0      | 11.9 MB   | #####1     |  51%
# pystan-2.19.0.0      | 11.9 MB   | ######     |  61%
# pystan-2.19.0.0      | 11.9 MB   | #######1   |  72%
# pystan-2.19.0.0      | 11.9 MB   | ########1  |  81%
# pystan-2.19.0.0      | 11.9 MB   | #########  |  91%
# pystan-2.19.0.0      | 11.9 MB   | #########9 | 100%
# pystan-2.19.0.0      | 11.9 MB   | ########## | 100%
#
# m2w64-bzip2-1.0.6    | 102 KB    |            |   0%
# m2w64-bzip2-1.0.6    | 102 KB    | ########## | 100%
# m2w64-bzip2-1.0.6    | 102 KB    | ########## | 100%
#
# m2w64-gcc-ada-5.3.0  | 33.3 MB   |            |   0%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | 1          |   1%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | 4          |   5%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | 8          |   8%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | #1         |  12%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | #5         |  15%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | #8         |  19%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | ##1        |  22%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | ##5        |  25%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | ##8        |  29%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | ###1       |  32%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | ###5       |  35%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | ###8       |  39%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | ####2      |  42%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | ####5      |  46%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | ####9      |  49%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | #####2     |  53%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | #####5     |  56%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | #####9     |  59%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | ######3    |  63%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | ######6    |  67%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | #######    |  70%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | #######3   |  74%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | #######7   |  77%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | ########   |  81%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | ########4  |  84%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | ########7  |  88%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | #########1 |  91%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | #########4 |  94%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | #########7 |  98%
# m2w64-gcc-ada-5.3.0  | 33.3 MB   | ########## | 100%
#
# m2w64-libmangle-git- | 23 KB     |            |   0%
# m2w64-libmangle-git- | 23 KB     | ########## | 100%
#
# m2w64-gcc-5.3.0      | 40.8 MB   |            |   0%
# m2w64-gcc-5.3.0      | 40.8 MB   | 1          |   2%
# m2w64-gcc-5.3.0      | 40.8 MB   | 3          |   4%
# m2w64-gcc-5.3.0      | 40.8 MB   | 6          |   7%
# m2w64-gcc-5.3.0      | 40.8 MB   | #          |  10%
# m2w64-gcc-5.3.0      | 40.8 MB   | #3         |  13%
# m2w64-gcc-5.3.0      | 40.8 MB   | #5         |  16%
# m2w64-gcc-5.3.0      | 40.8 MB   | #8         |  19%
# m2w64-gcc-5.3.0      | 40.8 MB   | ##2        |  22%
# m2w64-gcc-5.3.0      | 40.8 MB   | ##5        |  25%
# m2w64-gcc-5.3.0      | 40.8 MB   | ##8        |  28%
# m2w64-gcc-5.3.0      | 40.8 MB   | ###1       |  31%
# m2w64-gcc-5.3.0      | 40.8 MB   | ###4       |  34%
# m2w64-gcc-5.3.0      | 40.8 MB   | ###6       |  37%
# m2w64-gcc-5.3.0      | 40.8 MB   | ###9       |  40%
# m2w64-gcc-5.3.0      | 40.8 MB   | ####2      |  42%
# m2w64-gcc-5.3.0      | 40.8 MB   | ####5      |  45%
# m2w64-gcc-5.3.0      | 40.8 MB   | ####7      |  48%
# m2w64-gcc-5.3.0      | 40.8 MB   | #####      |  51%
# m2w64-gcc-5.3.0      | 40.8 MB   | #####3     |  53%
# m2w64-gcc-5.3.0      | 40.8 MB   | #####6     |  56%
# m2w64-gcc-5.3.0      | 40.8 MB   | #####9     |  59%
# m2w64-gcc-5.3.0      | 40.8 MB   | ######1    |  62%
# m2w64-gcc-5.3.0      | 40.8 MB   | ######4    |  65%
# m2w64-gcc-5.3.0      | 40.8 MB   | ######7    |  67%
# m2w64-gcc-5.3.0      | 40.8 MB   | #######    |  70%
# m2w64-gcc-5.3.0      | 40.8 MB   | #######3   |  73%
# m2w64-gcc-5.3.0      | 40.8 MB   | #######5   |  76%
# m2w64-gcc-5.3.0      | 40.8 MB   | #######8   |  79%
# m2w64-gcc-5.3.0      | 40.8 MB   | ########1  |  81%
# m2w64-gcc-5.3.0      | 40.8 MB   | ########4  |  84%
# m2w64-gcc-5.3.0      | 40.8 MB   | ########7  |  87%
# m2w64-gcc-5.3.0      | 40.8 MB   | ########9  |  90%
# m2w64-gcc-5.3.0      | 40.8 MB   | #########2 |  93%
# m2w64-gcc-5.3.0      | 40.8 MB   | #########5 |  95%
# m2w64-gcc-5.3.0      | 40.8 MB   | #########8 |  98%
# m2w64-gcc-5.3.0      | 40.8 MB   | ########## | 100%
#
# m2w64-windows-defaul | 5 KB      |            |   0%
# m2w64-windows-defaul | 5 KB      | ########## | 100%
#
# holidays-0.10.4      | 65 KB     |            |   0%
# holidays-0.10.4      | 65 KB     | ########## | 100%
# holidays-0.10.4      | 65 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/win-64::anaconda==custom=py37_1
#   - defaults/win-64::astropy==4.0=py37he774522_0
#   - defaults/win-64::bkcharts==0.2=py37_0
#   - defaults/win-64::bokeh==1.4.0=py37_0
#   - defaults/win-64::bottleneck==1.3.2=py37h2a96729_0
#   - defaults/noarch::dask==2.11.0=py_0
#   - defaults/win-64::gensim==3.8.0=py37hf9181ef_0
#   - defaults/win-64::h5py==2.10.0=py37h5e291fa_0
#   - defaults/win-64::imageio==2.6.1=py37_0
#   - defaults/noarch::keras-applications==1.0.8=py_1
#   - defaults/noarch::keras-preprocessing==1.1.0=py_1
#   - defaults/win-64::matplotlib==3.1.3=py37_0
#   - defaults/win-64::matplotlib-base==3.1.3=py37h64f37c6_0
#   - conda-forge/label/cf202003/noarch::missingno==0.4.2=py_1
#   - defaults/win-64::mkl_fft==1.0.15=py37h14836fe_0
#   - defaults/win-64::mkl_random==1.1.0=py37h675688f_0
#   - defaults/win-64::numba==0.48.0=py37h47e9c7a_0
#   - defaults/win-64::numexpr==2.7.1=py37h25d0782_0
#   - defaults/win-64::numpy==1.18.1=py37h93ca92e_0
#   - defaults/win-64::pandas==1.0.1=py37h47e9c7a_0
#   - defaults/win-64::patsy==0.5.1=py37_0
#   - conda-forge/noarch::pyspark==2.4.6=py_0
#   - defaults/win-64::pytables==3.6.1=py37h1da0976_0
#   - defaults/win-64::pytest-arraydiff==0.3=py37h39e3cac_0
#   - defaults/noarch::pytest-astropy==0.8.0=py_0
#   - defaults/noarch::pytest-doctestplus==0.5.0=py_0
#   - defaults/win-64::pywavelets==1.1.1=py37he774522_0
#   - defaults/win-64::scikit-image==0.16.2=py37h47e9c7a_0
#   - defaults/win-64::scikit-learn==0.22.1=py37h6288b17_0
#   - defaults/win-64::scipy==1.4.1=py37h9439919_0
#   - defaults/noarch::seaborn==0.10.0=py_0
#   - defaults/win-64::statsmodels==0.11.0=py37he774522_0
#   - defaults/win-64::tensorboard==1.14.0=py37he3c9ec2_0
#   - defaults/win-64::tensorflow==1.14.0=eigen_py37hcf3f253_0
#   - defaults/win-64::tensorflow-base==1.14.0=eigen_py37hdbc3f0e_0
#   - defaults/noarch::tensorflow-estimator==1.14.0=py_0
#   - defaults/win-64::_anaconda_depends==2020.07=py37_0

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import pandas_datareader.data as web
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from fbprophet import Prophet
from datetime import datetime
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
# 한글 폰트 문제 해결

import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry')

# %%
pinkwink_web = pd.read_csv('C:/Users/A/Downloads/DataScience-master/data/08. PinkWink Web Traffic.csv', encoding='utf-8', thousands=',',
                          names=['date', 'hit'], index_col=0)
pinkwink_web = pinkwink_web[pinkwink_web['hit'].notnull()]
pinkwink_web.head()
# Out:
#              hit
# date
# 16. 7. 1.  766.0
# 16. 7. 2.  377.0
# 16. 7. 3.  427.0
# 16. 7. 4.  902.0
# 16. 7. 5.  850.0

# %%
pinkwink_web['hit'].plot(figsize=(12,4), grid=True)

# %%
time = np.arange(0, len(pinkwink_web))
traffic = pinkwink_web['hit'].values

fx = np.linspace(0, time[-1], 1000)

# %%
def error(f,x,y):
    return np.sqrt(np.mean((f(x)-y)**2))

# %%
fp1 = np.polyfit(time, traffic, 1)
f1 = np.poly1d(fp1)

f2p = np.polyfit(time, traffic, 2)
f2 = np.poly1d(f2p)

f3p = np.polyfit(time, traffic, 3)
f3 = np.poly1d(f3p)

f15p = np.polyfit(time, traffic, 15)
f15 = np.poly1d(f15p)

print(error(f1, time, traffic))
print(error(f2, time, traffic))
print(error(f3, time, traffic))
print(error(f15, time, traffic))
# Out:
# 430.85973081109626
# 430.6284101894695
# 429.53280466762925
# 330.4777304274343

# %%
plt.figure(figsize=(10,6))
plt.scatter(time, traffic, s=10)

plt.plot(fx, f1(fx), lw=4, label='f1')
plt.plot(fx, f2(fx), lw=4, label='f2')
plt.plot(fx, f3(fx), lw=4, label='f3')
plt.plot(fx, f15(fx), lw=4, label='f15')

plt.grid(True, linestyle='-', color='0.75')
plt.legend(loc=2)
plt.show()
