# %% [markdown]
# 구글은 임베딩 프로젝터(embedding projector)라는 데이터 시각화 도구를 지원
#
# ## 1. 워드 임베딩 모델로부터 2개의 tsv 파일 생성하기
# * Word2Vec, GloVe, 등 다양한 방법으로 훈련되어 있어도 상관 없다.
# * 모델이 미리 학습하고, 파일로 저장되어 있어야 한다.

# %%
# 시각화에 필요한 자료 생성
# !python -m gensim.scripts.word2vec2tensor --input ./data/eng_w2v --output ./data/eng_w2v
# Out:
# C:\Users\A\anaconda3\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\A\anaconda3\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# C:\Users\A\anaconda3\lib\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
#   stacklevel=1)
# 2021-06-22 22:27:00,612 - word2vec2tensor - INFO - running C:\Users\A\anaconda3\lib\site-packages\gensim\scripts\word2vec2tensor.py --input ./data/eng_w2v --output ./data/eng_w2v
# 2021-06-22 22:27:00,612 - utils_any2vec - INFO - loading projection weights from ./data/eng_w2v
# 2021-06-22 22:27:02,577 - utils_any2vec - INFO - loaded (21613, 100) matrix from ./data/eng_w2v
# 2021-06-22 22:27:05,248 - word2vec2tensor - INFO - 2D tensor file saved to ./data/eng_w2v_tensor.tsv
# 2021-06-22 22:27:05,248 - word2vec2tensor - INFO - Tensor metadata file saved to ./data/eng_w2v_metadata.tsv
# ...

# %% [markdown]
# ## 2. 임베딩 프로젝터를 사용하여 시각화하기
# 링크 : https://projector.tensorflow.org/
#
# 링크에 접속하여 생성한 자료 두개를 업로드
#
# * 복잡한 데이터를 차원을 축소하여 시각화 할 수 있도록 도와주는 PCA, t-SNE 등을 제공
# * 이 외에도 다양한 기능 제공

# %%
from IPython.display import Image
Image('./data/구글 임베딩 프로젝터.png')
