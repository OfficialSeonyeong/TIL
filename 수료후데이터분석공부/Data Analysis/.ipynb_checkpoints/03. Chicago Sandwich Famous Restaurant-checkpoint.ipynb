# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
page = open("C:/Users/A/Downloads/DataScience-master/data/03. test_first.html", 'r').read()
soup = BeautifulSoup(page, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Very Simple HTML Code by PinkWink
#   </title>
#  </head>
#  <body>
#   <div>
#    <p class="inner-text first-item" id="first">
#     Happy PinkWink.
#     <a href="http://www.pinkwink.kr" id="pw-link">
#      PinkWink
#     </a>
#    </p>
#    <p class="inner-text second-item">
#     Happy Data Science.
#     <a href="https://www.python.org" id="py-link">
#      Python
#     </a>
#    </p>
#   </div>
#   <p class="outer-text first-item" id="second">
#    <b>
#     Data Science is funny.
#    </b>
#   </p>
#   <p class="outer-text">
#    <b>
#     All I need is Love.
#    </b>
#   </p>
#  </body>
# </html>

# %%
list(soup.children)
# Out:
# ['html',
#  '\n',
#  <html>
#  <head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>
#  <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>
#  </html>]

# %%
html = list(soup.children)[2]
html
# Out:
# <html>
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>
# </html>

# %%
list(html.children)
# Out:
# ['\n',
#  <head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>,
#  '\n',
#  <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>,
#  '\n']

# %%
body = list(html.children)[3]
body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
soup.body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
list(body.children)
# Out:
# ['\n',
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>,
#  '\n',
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  '\n',
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>,
#  '\n']

# %%
soup.find_all('p')
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>,
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>,
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
soup.find('p')
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
soup.find_all('p', class_='outer-text')
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
soup.find_all(class_='outer-text')
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>]

# %%
soup.find_all(id='first')
# Out:
# [<p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
#  </p>]

# %%
soup.head
# Out:
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>

# %%
soup.head.next_sibling
# Out:
# '\n'

# %%
soup.head.next_sibling.next_sibling
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
body.p
# Out:
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>
# </p>

# %%
body.p.next_sibling.next_sibling
# Out:
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>

# %%
for each_tag in soup.find_all('p'):
    print(each_tag.get_text())
# Out:
#                 Happy PinkWink.
#                 PinkWink
#
#
#                 Happy Data Science.
#                 Python
#
#
#
#                 Data Science is funny.
#
#
#
#
#                 All I need is Love.

# %%
body.get_text()
# Out:
# '\n\n\n                Happy PinkWink.\n                PinkWink\n\n\n                Happy Data Science.\n                Python\n\n\n\n\n                Data Science is funny.\n            \n\n\n\n                All I need is Love.\n            \n\n'

# %%
links = soup.find_all('a')
links
# Out:
# [<a href="http://www.pinkwink.kr" id="pw-link">PinkWink</a>,
#  <a href="https://www.python.org" id="py-link">Python</a>]

# %%
for each in links:
    href = each['href']
    text = each.string
    print(text + ' -> '+ href)
# Out:
# PinkWink -> http://www.pinkwink.kr
# Python -> https://www.python.org

# %% [markdown]
# ### 네이버 영화 평점 기준 영화의 평점 변화 확인

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
from urllib.request import urlopen

page = 'https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&date=20210119'

soup = BeautifulSoup(urlopen(page), 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 " property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="랭킹 : 네이버 영화" property="og:title"/>
# <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&amp;date=20210119" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %%
soup.find_all('div',class_='tit5')
# Out:
# [<div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=196843" title="극장판 바이올렛 에버가든">극장판 바이올렛 에버가든</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=197647" title="가나의 혼인잔치: 언약">가나의 혼인잔치: 언약</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=182525" title="언플랜드">언플랜드</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=194334" title="부활: 그 증거">부활: 그 증거</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=10244" title="늑대와 춤을">늑대와 춤을</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=16531" title="인생">인생</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=195687" title="페이트 스테이 나이트 헤븐즈필 III.스프링 송">페이트 스테이 나이트 헤븐즈필 III.스프링 송</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=17942" title="제리 맥과이어">제리 맥과이어</a>
#  </div>,
#  <div class="tit5">
# ...

# %%
soup.find_all('div','tit5')[0].a.string
# Out:
# '극장판 바이올렛 에버가든'

# %%
soup.find_all('td','point')[0].string
# Out:
# '9.52'

# %%
date = pd.date_range('2020-12-1', periods=30, freq='D')
date
# Out:
# DatetimeIndex(['2020-12-01', '2020-12-02', '2020-12-03', '2020-12-04',
#                '2020-12-05', '2020-12-06', '2020-12-07', '2020-12-08',
#                '2020-12-09', '2020-12-10', '2020-12-11', '2020-12-12',
#                '2020-12-13', '2020-12-14', '2020-12-15', '2020-12-16',
#                '2020-12-17', '2020-12-18', '2020-12-19', '2020-12-20',
#                '2020-12-21', '2020-12-22', '2020-12-23', '2020-12-24',
#                '2020-12-25', '2020-12-26', '2020-12-27', '2020-12-28',
#                '2020-12-29', '2020-12-30'],
#               dtype='datetime64[ns]', freq='D')

# %%
import urllib
from tqdm import tqdm_notebook
    
movie_date = []
movie_name = []
movie_point = []

for today in tqdm_notebook(date):
    html = 'https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&date={date}'
    response = urlopen(html.format(date=urllib.parse.quote(today.strftime('%Y%m%d'))))
    soup = BeautifulSoup(response, 'html.parser')
    
    end = len(soup.find_all('td','point'))
    
    movie_date.extend([today for n in range(0,end)])
    movie_name.extend([soup.find_all('div','tit5')[n].a.string for n in range(0,end)])
    movie_point.extend([soup.find_all('td','point')[n].string for n in range(0,end)])

# %%
movie_name
# Out:
# ['극장판 바이올렛 에버가든',
#  '부활: 그 증거',
#  '소년시절의 너',
#  '페이트 스테이 나이트 헤븐즈필 III.스프링 송',
#  '톰보이',
#  '사랑의 블랙홀',
#  '타오르는 여인의 초상',
#  '당신이 잠든 사이에',
#  '노트북',
#  '타샤 튜더',
#  '비긴 어게인',
#  '온워드: 단 하루의 기적',
#  '윤희에게',
#  '남매의 여름밤',
#  '담보',
#  '해리가 샐리를 만났을 때',
#  '1917',
#  '에이미',
#  '미스터트롯: 더 무비',
#  '위플래쉬',
#  '너의 이름은.',
#  '찬실이는 복도 많지',
#  '귀여운 여인',
#  '잠수종과 나비',
#  '퐁네프의 연인들',
#  '라라랜드',
#  '킹덤 오브 헤븐: 디렉터스 컷',
#  '렛 미 인',
#  '지옥의 묵시록',
#  '삼진그룹 영어토익반',
#  '레볼루셔너리 로드',
#  '셔터 아일랜드',
#  '런',
#  '테넷',
#  '내가 죽던 날',
#  '날씨의 아이',
#  '로미오와 줄리엣',
#  '레버넌트: 죽음에서 돌아온 자',
#  '펀치 드렁크 러브',
#  '아치와 씨팍',
#  '도굴',
#  '초미의 관심사',
#  '아가씨',
#  '호랑이보다 무서운 겨울손님',
#  '투 마더스',
#  '프리키 데스데이',
#  '기기괴괴 성형수',
#  '그린랜드',
#  '이웃사촌',
#  '오케이 마담',
#  '극장판 바이올렛 에버가든',
#  '부활: 그 증거',
#  '소년시절의 너',
#  '페이트 스테이 나이트 헤븐즈필 III.스프링 송',
#  '톰보이',
#  '사랑의 블랙홀',
#  '타오르는 여인의 초상',
#  '당신이 잠든 사이에',
#  '노트북',
#  '타샤 튜더',
#  '비긴 어게인',
#  '온워드: 단 하루의 기적',
#  '남매의 여름밤',
#  '담보',
#  '해리가 샐리를 만났을 때',
#  '1917',
#  '에이미',
#  '미스터트롯: 더 무비',
# ...

# %%
movie = pd.DataFrame({'date':movie_date, 'name':movie_name, 'point':movie_point})
movie.head()
# Out:
#         date                        name point
# 0 2020-12-01               극장판 바이올렛 에버가든  9.51
# 1 2020-12-01                    부활: 그 증거  9.43
# 2 2020-12-01                     소년시절의 너  9.40
# 3 2020-12-01  페이트 스테이 나이트 헤븐즈필 III.스프링 송  9.23
# 4 2020-12-01                         톰보이  9.20

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1476 entries, 0 to 1475
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1476 non-null   datetime64[ns]
#  1   name    1476 non-null   object
#  2   point   1476 non-null   object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 34.7+ KB

# %%
movie.point = movie['point'].map(lambda x: float(x))

# %%
import numpy as np

movie_unique = pd.pivot_table(movie, index='name', aggfunc=np.sum)
movie_best = movie_unique.sort_values(by='point', ascending=False)
movie_best.head()
# Out:
#                 point
# name
# 극장판 바이올렛 에버가든  285.10
# 부활: 그 증거       282.36
# 사랑의 블랙홀        274.47
# 당신이 잠든 사이에     271.74
# 노트북            271.50

# %%
tmp = movie.query('name == ["극장판 바이올렛 에버가든"]')
tmp
# Out:
#            date           name  point
# 0    2020-12-01  극장판 바이올렛 에버가든   9.51
# 50   2020-12-02  극장판 바이올렛 에버가든   9.50
# 99   2020-12-03  극장판 바이올렛 에버가든   9.51
# 149  2020-12-04  극장판 바이올렛 에버가든   9.50
# 199  2020-12-05  극장판 바이올렛 에버가든   9.50
# 249  2020-12-06  극장판 바이올렛 에버가든   9.51
# 299  2020-12-07  극장판 바이올렛 에버가든   9.51
# 349  2020-12-08  극장판 바이올렛 에버가든   9.52
# 399  2020-12-09  극장판 바이올렛 에버가든   9.52
# 449  2020-12-10  극장판 바이올렛 에버가든   9.51
# 499  2020-12-11  극장판 바이올렛 에버가든   9.50
# 549  2020-12-12  극장판 바이올렛 에버가든   9.51
# 599  2020-12-13  극장판 바이올렛 에버가든   9.51
# 649  2020-12-14  극장판 바이올렛 에버가든   9.50
# 699  2020-12-15  극장판 바이올렛 에버가든   9.51
# 749  2020-12-16  극장판 바이올렛 에버가든   9.51
# 799  2020-12-17  극장판 바이올렛 에버가든   9.50
# 850  2020-12-18  극장판 바이올렛 에버가든   9.50
# 900  2020-12-19  극장판 바이올렛 에버가든   9.50
# 950  2020-12-20  극장판 바이올렛 에버가든   9.51
# 1000 2020-12-21  극장판 바이올렛 에버가든   9.51
# 1050 2020-12-22  극장판 바이올렛 에버가든   9.50
# 1100 2020-12-23  극장판 바이올렛 에버가든   9.50
# 1150 2020-12-24  극장판 바이올렛 에버가든   9.50
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(12,8))
plt.plot(tmp['date'], tmp['point'])
plt.legend(loc='best')
plt.grid()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
movie_pivot = pd.pivot_table(movie, index=['date'], columns=['name'], values=['point'])
movie_pivot.head()
# Out:
#            point                                                     \
# name        1917 69세 800 가나의 혼인잔치: 언약 가장 따뜻한 색, 블루 경계선 귀여운 여인  그린랜드
# date
# 2020-12-01  8.86 NaN NaN          NaN          NaN NaN    8.7  6.86
# 2020-12-02  8.86 NaN NaN          NaN          NaN NaN    8.7  6.85
# 2020-12-03  8.86 NaN NaN          NaN          NaN NaN    8.7   NaN
# 2020-12-04  8.86 NaN NaN          NaN          NaN NaN    8.7   NaN
# 2020-12-05  8.86 NaN NaN          NaN          NaN NaN    8.7   NaN
#
#                                        ...            \
# name       극장판 바이올렛 에버가든 극장판 원피스 스탬피드  ... 펀치 드렁크 러브
# date                                   ...
# 2020-12-01          9.51          NaN  ...      7.75
# 2020-12-02          9.50          NaN  ...      7.75
# 2020-12-03          9.51         8.78  ...      7.75
# 2020-12-04          9.50         8.78  ...      7.75
# 2020-12-05          9.50         8.78  ...      7.75
#
# ...

# %%
movie_pivot.columns = movie_pivot.columns.droplevel()

# %%
movie_pivot.head()
# Out:
# name        1917  69세  800  가나의 혼인잔치: 언약  가장 따뜻한 색, 블루  경계선  귀여운 여인  그린랜드  \
# date
# 2020-12-01  8.86  NaN  NaN           NaN           NaN  NaN     8.7  6.86
# 2020-12-02  8.86  NaN  NaN           NaN           NaN  NaN     8.7  6.85
# 2020-12-03  8.86  NaN  NaN           NaN           NaN  NaN     8.7   NaN
# 2020-12-04  8.86  NaN  NaN           NaN           NaN  NaN     8.7   NaN
# 2020-12-05  8.86  NaN  NaN           NaN           NaN  NaN     8.7   NaN
#
# name        극장판 바이올렛 에버가든  극장판 원피스 스탬피드  ...  펀치 드렁크 러브  \
# date                                     ...
# 2020-12-01           9.51           NaN  ...       7.75
# 2020-12-02           9.50           NaN  ...       7.75
# 2020-12-03           9.51          8.78  ...       7.75
# 2020-12-04           9.50          8.78  ...       7.75
# 2020-12-05           9.50          8.78  ...       7.75
#
# name        페이트 스테이 나이트 헤븐즈필 III.스프링 송  퐁네프의 연인들  프란츠  프리키 데스데이  피아노  하나와 앨리스  \
# date
# ...
