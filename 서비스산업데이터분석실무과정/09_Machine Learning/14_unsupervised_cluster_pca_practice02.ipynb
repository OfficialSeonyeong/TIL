# %% [markdown]
# #### 학습목표
# - 서울 시내 중학교 진학률 데이터 세트 (지역에 따른 군집)
# - LabelEncoder, OnHotEncoder 필요
# - 지도 시각화(위도, 경도) -> folium

# %%
from sklearn.cluster import KMeans

import pandas as pd
import numpy as np
import folium

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_excel('./data/middle_shcool_graduates_report.xlsx')
df.head()
# Out:
#     지역               학교명  코드  유형  주야  남학생수  여학생수    일반고   특성화고    과학고  외고_국제고  \
# 0  성북구    서울대학교사범대학부설중학교   3  국립  주간   277     0  0.585  0.148  0.018   0.007
# 1  종로구  서울대학교사범대학부설여자중학교   3  국립  주간     0   256  0.680  0.199  0.000   0.035
# 2  강남구             개원중학교   3  공립  주간   170   152  0.817  0.047  0.009   0.012
# 3  강남구             개포중학교   3  공립  주간    83    72  0.755  0.097  0.013   0.013
# 4  서초구             경원중학교   3  공립  주간   199   212  0.669  0.017  0.007   0.010
#
#    예고_체고  마이스터고    자사고    자공고   기타진학  취업     미상         위도          경도
# 0  0.000  0.011  0.227  0.000  0.004   0  0.000  37.594942  127.038909
# 1  0.008  0.000  0.043  0.004  0.031   0  0.000  37.577473  127.003857
# 2  0.003  0.006  0.090  0.003  0.009   0  0.003  37.491637  127.071744
# 3  0.019  0.019  0.065  0.000  0.019   0  0.000  37.480439  127.062201
# 4  0.005  0.000  0.282  0.000  0.010   0  0.000  37.510750  127.008900

# %%
df.columns.values
# Out:
# array(['지역', '학교명', '코드', '유형', '주야', '남학생수', '여학생수', '일반고', '특성화고',
#        '과학고', '외고_국제고', '예고_체고', '마이스터고', '자사고', '자공고', '기타진학', '취업',
#        '미상', '위도', '경도'], dtype=object)

# %%
# 지도에 위치 표시
school_map = folium.Map(location=[37.55, 126.98], titles='Stamen Terrain', zoom_start=12)
    
for name, lat, lng in zip(df.학교명, df.위도, df.경도):
    folium.CircleMarker([lat, lng], radius=5, color='g', fill=True, fill_color='black', fill_opacity=0.5, popup=name).add_to(school_map)

school_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrap
# ...

# %%
# 진행결과
# 데이터 전처리 - 원핫 인코딩
# 군집 모형 생성 - 분석에 사용할 피처는 과학고, 외고국제고, 자사고 진학률
# 표준화
# 모형 객체 생성
# 모형 학습
# 예측
# 예측 결과를 데이터 프레임에 추가
# 클러스터 값으로 그룹화, 그룹별 내용 출력
# 지도 그래프로 시각화

# %%
df02 = df.iloc[:,[1,8,9,10,-2,-1]]

# 표준화 진행
from sklearn.preprocessing import StandardScaler

feature = df02.iloc[:,[1,2,3]]

Standard = StandardScaler()
standard_school = Standard.fit_transform(feature)
school_df =  pd.DataFrame(standard_school)

kmeans = KMeans(n_clusters=3)
fitted_school = kmeans.fit(school_df)

df['clu_id'] = fitted_school.labels_
df
# Out:
#       지역               학교명  코드  유형  주야  남학생수  여학생수    일반고   특성화고    과학고  ...  \
# 0    성북구    서울대학교사범대학부설중학교   3  국립  주간   277     0  0.585  0.148  0.018  ...
# 1    종로구  서울대학교사범대학부설여자중학교   3  국립  주간     0   256  0.680  0.199  0.000  ...
# 2    강남구             개원중학교   3  공립  주간   170   152  0.817  0.047  0.009  ...
# 3    강남구             개포중학교   3  공립  주간    83    72  0.755  0.097  0.013  ...
# 4    서초구             경원중학교   3  공립  주간   199   212  0.669  0.017  0.007  ...
# ..   ...               ...  ..  ..  ..   ...   ...    ...    ...    ...  ...
# 410  강남구           국립국악중학교   9  국립  주간     9    91  0.060  0.000  0.000  ...
# 411  금천구         국립전통예술중학교   9  국립  주간    14    42  0.107  0.000  0.000  ...
# 412  광진구            선화예술학교   9  사립  주간    33   241  0.102  0.000  0.000  ...
# 413   중구              예원학교   9  사립  주간    31   258  0.170  0.000  0.000  ...
# 414  노원구           한국삼육중학교   9  사립  주간   105   102  0.908  0.019  0.000  ...
#
# ...

# %%
df.groupby(['clu_id'])['지역'].count()
# Out:
# clu_id
# 0     72
# 1    201
# 2    142
# Name: 지역, dtype: int64

# %%
# 지도에 위치 표시
school_map = folium.Map(location=[37.55, 126.98], titles='Stamen Terrain', zoom_start=12)

for name, lat, lng, clu_id in zip(df.학교명, df.위도, df.경도, df.clu_id):
    if clu_id == 0:
        folium.CircleMarker([lat, lng], radius=5, color='g', fill=True, fill_color='green', fill_opacity=0.5, popup=name).add_to(school_map)
    elif clu_id == 1:
        folium.CircleMarker([lat, lng], radius=5, color='y', fill=True, fill_color='yellow', fill_opacity=0.5, popup=name).add_to(school_map)
    elif clu_id == 2:
        folium.CircleMarker([lat, lng], radius=5, color='r', fill=True, fill_color='red', fill_opacity=0.5, popup=name).add_to(school_map)
        

school_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrap
# ...
